# %% [markdown]
# ##**Задания практической работы**

# %% [markdown]
# **1.Создание DataFrame разными способами**<br>
#
# 1. Создайте DataFrame из словаря списков с данными о пяти сотрудниках
# (возьмите из таблицы 1).
# 2. Создайте DataFrame из списка словарей с теми же данными.
# 3. Создайте DataFrame из массива NumPy, заполненного случайными числами
# от 20 до 60 (для возраста сотрудников).
# 4. Проверьте типы данных в каждом столбце с помощью .info()

# %%
import pandas as pd
import numpy as np

data = {
    'ID': [1, 2, 3, 4, 5],
    'Имя': ['Иван', 'Ольга', 'Алексей', 'Мария', 'Сергей'],
    'Возраст': [25, 30, 40, 35, 28],
    'Должность': ['Инженер', 'Аналитик', 'Менеджер', 'Программист', 'Специалист'],
    'Отдел': ['IT', 'Маркетинг', 'Продажи', 'IT', 'HR'],
    'Зарплата': [60000, 75000, 90000, 80000, 50000],
    'Стаж работы': [2, 5, 15, 7, 3]
}

df = pd.DataFrame(data)
print(df.info())
df.style.set_sticky()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           5 non-null      int64
#  1   Имя          5 non-null      object
#  2   Возраст      5 non-null      int64
#  3   Должность    5 non-null      object
#  4   Отдел        5 non-null      object
#  5   Зарплата     5 non-null      int64
#  6   Стаж работы  5 non-null      int64
# dtypes: int64(4), object(3)
# memory usage: 412.0+ bytes
# None
# <style type="text/css">
# #T_d1b73 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_d1b73 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_d1b73">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
data = [
    {'ID':1,'Имя':'Иван','Возраст':25,'Должность':'Инженер','Отдел':'IT','Зарплата':60000,'Стаж работы':2},
    {'ID':2,'Имя':'Ольга','Возраст':30,'Должность':'Аналитик','Отдел':'Маркетинг','Зарплата':75000,'Стаж работы':5},
    {'ID':3,'Имя':'Алексей','Возраст':40,'Должность':'Менеджер','Отдел':'Продажи','Зарплата':90000,'Стаж работы':15},
    {'ID':4,'Имя':'Мария','Возраст':35,'Должность':'Программист','Отдел':'IT','Зарплата':80000,'Стаж работы':7},
    {'ID':5,'Имя':'Сергей','Возраст':28,'Должность':'Специалист','Отдел':'HR','Зарплата':50000,'Стаж работы':3}
]

df = pd.DataFrame(data)
print(df.info())
df.style.set_sticky()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           5 non-null      int64
#  1   Имя          5 non-null      object
#  2   Возраст      5 non-null      int64
#  3   Должность    5 non-null      object
#  4   Отдел        5 non-null      object
#  5   Зарплата     5 non-null      int64
#  6   Стаж работы  5 non-null      int64
# dtypes: int64(4), object(3)
# memory usage: 412.0+ bytes
# None
# <style type="text/css">
# #T_dacc3 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_dacc3 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_dacc3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
data = np.random.randint(20, 61, size=5)
df = pd.DataFrame({"ID":[1,2,3,4,5],'Возраст': data})
print(df.info())
df.style.set_sticky()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       5 non-null      int64
#  1   Возраст  5 non-null      int32
# dtypes: int32(1), int64(1)
# memory usage: 192.0 bytes
# None
# <style type="text/css">
# #T_9e26f thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_9e26f tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_9e26f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e26f_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_9e26f_level0_col1" class="col_heading level0 col1" >Возраст</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e26f_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# **2.Чтение данных из файлов ( CSV , Excel , JSON)** <br>
# Используйте предоставленные таблицы и сохраните их в файлы перед чтением<br>
# 1. Сохраните Таблицу 1 в CSV и затем загрузите ее обратно в DataFrame .
# 2. Запишите Таблицу 2 в Excel ( data.xlsx , лист "Клиенты" ) и прочитайте ее в
# DataFrame .
# 3. Экспортируйте Таблицу 1 в формат JSON и затем прочитайте ее обратно в
# DataFrame.
#
# Выведите первые 5 строк загруженных DataFrame.

# %%
data1 = [
    {'ID':1,'Имя':'Иван','Возраст':25,'Должность':'Инженер','Отдел':'IT','Зарплата':60000,'Стаж работы':2},
    {'ID':2,'Имя':'Ольга','Возраст':30,'Должность':'Аналитик','Отдел':'Маркетинг','Зарплата':75000,'Стаж работы':5},
    {'ID':3,'Имя':'Алексей','Возраст':40,'Должность':'Менеджер','Отдел':'Продажи','Зарплата':90000,'Стаж работы':15},
    {'ID':4,'Имя':'Мария','Возраст':35,'Должность':'Программист','Отдел':'IT','Зарплата':80000,'Стаж работы':7},
    {'ID':5,'Имя':'Сергей','Возраст':28,'Должность':'Специалист','Отдел':'HR','Зарплата':50000,'Стаж работы':3},
    {'ID':6,'Имя':'Анна','Возраст':32,'Должность':'Разработчик','Отдел':'IT','Зарплата':85000,'Стаж работы':6},
    {'ID':7,'Имя':'Дмитрий','Возраст':45,'Должность':'HR','Отдел':'HR','Зарплата':48000,'Стаж работы':12},
    {'ID':8,'Имя':'Елена','Возраст':29,'Должность':'Маркетолог','Отдел':'Маркетинг','Зарплата':70000,'Стаж работы':4},
    {'ID':9,'Имя':'Виктор','Возраст':31,'Должность':'Юрист','Отдел':'Юридический','Зарплата':95000,'Стаж работы':10},
    {'ID':10,'Имя':'Алиса','Возраст':27,'Должность':'Дизайнер','Отдел':'Дизайн','Зарплата':62000,'Стаж работы':5},
    {'ID':11,'Имя':'Павел','Возраст':33,'Должность':'Администратор','Отдел':'Администрация','Зарплата':55000,'Стаж работы':7},
    {'ID':12,'Имя':'Светлана','Возраст':26,'Должность':'Тестировщик','Отдел':'Тестирование','Зарплата':67000,'Стаж работы':2},
    {'ID':13,'Имя':'Роман','Возраст':42,'Должность':'Финансист','Отдел':'Финансы','Зарплата':105000,'Стаж работы':20},
    {'ID':14,'Имя':'Татьяна','Возраст':37,'Должность':'Редактор','Отдел':'Редакция','Зарплата':72000,'Стаж работы':9},
    {'ID':15,'Имя':'Николай','Возраст':39,'Должность':'Логист','Отдел':'Логистика','Зарплата':75000,'Стаж работы':11},
    {'ID':16,'Имя':'Валерия','Возраст':24,'Должность':'SEO-специалист','Отдел':'SEO','Зарплата':64000,'Стаж работы':3},
    {'ID':17,'Имя':'Григорий','Возраст':50,'Должность':'Бухгалтер','Отдел':'Бухгалтерия','Зарплата':110000,'Стаж работы':25},
    {'ID':18,'Имя':'Юлия','Возраст':45,'Должность':'Директор','Отдел':'Финансы','Зарплата':150000,'Стаж работы':20},
    {'ID':19,'Имя':'Степан','Возраст':41,'Должность':'Экономист','Отдел':'Экономика','Зарплата':98000,'Стаж работы':14},
    {'ID':20,'Имя':'Василиса','Возраст':38,'Должность':'Проект-менеджер','Отдел':'Продажи','Зарплата':88000,'Стаж работы':8}
]

df = pd.DataFrame(data1)

df.to_csv('dataz.csv', index=False)
d = pd.read_csv('dataz.csv')
d.head(5).style.set_sticky()
# Out:
# <style type="text/css">
# #T_e9b23 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_e9b23 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_e9b23">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9b23_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_e9b23_level0_col1" class="col_heading level0 col1" >Имя</th>
#       <th id="T_e9b23_level0_col2" class="col_heading level0 col2" >Возраст</th>
#       <th id="T_e9b23_level0_col3" class="col_heading level0 col3" >Должность</th>
#       <th id="T_e9b23_level0_col4" class="col_heading level0 col4" >Отдел</th>
#       <th id="T_e9b23_level0_col5" class="col_heading level0 col5" >Зарплата</th>
#       <th id="T_e9b23_level0_col6" class="col_heading level0 col6" >Стаж работы</th>
#     </tr>
#   </thead>
# ...

# %%
data2 = [
    {'ID':1,'Имя':'Иван','Возраст':34,'Город':'Москва','Баланс на счете':120000,'Кредитная история':'Хорошая'},
    {'ID':2,'Имя':'Ольга','Возраст':27,'Город':'Санкт-Петербург','Баланс на счете':80000,'Кредитная история':'Средняя'},
    {'ID':3,'Имя':'Алексей','Возраст':45,'Город':'Казань','Баланс на счете':150000,'Кредитная история':'Плохая'},
    {'ID':4,'Имя':'Мария','Возраст':38,'Город':'Новосибирск','Баланс на счете':200000,'Кредитная история':'Хорошая'},
    {'ID':5,'Имя':'Сергей','Возраст':29,'Город':'Екатеринбург','Баланс на счете':95000,'Кредитная история':'Средняя'},
    {'ID':6,'Имя':'Анна','Возраст':50,'Город':'Воронеж','Баланс на счете':300000,'Кредитная история':'Отличная'},
    {'ID':7,'Имя':'Дмитрий','Возраст':31,'Город':'Челябинск','Баланс на счете':140000,'Кредитная история':'Средняя'},
    {'ID':8,'Имя':'Елена','Возраст':40,'Город':'Краснодар','Баланс на счете':175000,'Кредитная история':'Хорошая'},
    {'ID':9,'Имя':'Виктор','Возраст':28,'Город':'Ростов-на-Дону','Баланс на счете':110000,'Кредитная история':'Плохая'},
    {'ID':10,'Имя':'Алиса','Возраст':33,'Город':'Уфа','Баланс на счете':98000,'Кредитная история':'Средняя'},
    {'ID':11,'Имя':'Павел','Возраст':46,'Город':'Омск','Баланс на счете':250000,'Кредитная история':'Хорошая'},
    {'ID':12,'Имя':'Светлана','Возраст':37,'Город':'Пермь','Баланс на счете':210000,'Кредитная история':'Отличная'},
    {'ID':13,'Имя':'Роман','Возраст':41,'Город':'Тюмень','Баланс на счете':135000,'Кредитная история':'Средняя'},
    {'ID':14,'Имя':'Татьяна','Возраст':25,'Город':'Саратов','Баланс на счете':155000,'Кредитная история':'Хорошая'},
    {'ID':15,'Имя':'Николай','Возраст':39,'Город':'Самара','Баланс на счете':125000,'Кредитная история':'Средняя'},
    {'ID':16,'Имя':'Валерия','Возраст':42,'Город':'Волгоград','Баланс на счете':180000,'Кредитная история':'Плохая'},
    {'ID':17,'Имя':'Григорий','Возраст':49,'Город':'Барнаул','Баланс на счете':275000,'Кредитная история':'Отличная'},
    {'ID':18,'Имя':'Юлия','Возраст':50,'Город':'Иркутск','Баланс на счете':320000,'Кредитная история':'Хорошая'},
    {'ID':19,'Имя':'Степан','Возраст':30,'Город':'Хабаровск','Баланс на счете':105000,'Кредитная история':'Средняя'},
    {'ID':20,'Имя':'Василиса','Возраст':35,'Город':'Томск','Баланс на счете':90000,'Кредитная история':'Плохая'}
]

df = pd.DataFrame(data2)

df.to_excel('dataz.xlsx', index=False)
d = pd.read_excel('dataz.xlsx')
d.head(5).style.set_sticky()
# Out:
# <style type="text/css">
# #T_ebb9b thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_ebb9b tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_ebb9b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebb9b_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_ebb9b_level0_col1" class="col_heading level0 col1" >Имя</th>
#       <th id="T_ebb9b_level0_col2" class="col_heading level0 col2" >Возраст</th>
#       <th id="T_ebb9b_level0_col3" class="col_heading level0 col3" >Город</th>
#       <th id="T_ebb9b_level0_col4" class="col_heading level0 col4" >Баланс на счете</th>
#       <th id="T_ebb9b_level0_col5" class="col_heading level0 col5" >Кредитная история</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
data1 = [
    {'ID':1,'Имя':'Иван','Возраст':25,'Должность':'Инженер','Отдел':'IT','Зарплата':60000,'Стаж работы':2},
    {'ID':2,'Имя':'Ольга','Возраст':30,'Должность':'Аналитик','Отдел':'Маркетинг','Зарплата':75000,'Стаж работы':5},
    {'ID':3,'Имя':'Алексей','Возраст':40,'Должность':'Менеджер','Отдел':'Продажи','Зарплата':90000,'Стаж работы':15},
    {'ID':4,'Имя':'Мария','Возраст':35,'Должность':'Программист','Отдел':'IT','Зарплата':80000,'Стаж работы':7},
    {'ID':5,'Имя':'Сергей','Возраст':28,'Должность':'Специалист','Отдел':'HR','Зарплата':50000,'Стаж работы':3},
    {'ID':6,'Имя':'Анна','Возраст':32,'Должность':'Разработчик','Отдел':'IT','Зарплата':85000,'Стаж работы':6},
    {'ID':7,'Имя':'Дмитрий','Возраст':45,'Должность':'HR','Отдел':'HR','Зарплата':48000,'Стаж работы':12},
    {'ID':8,'Имя':'Елена','Возраст':29,'Должность':'Маркетолог','Отдел':'Маркетинг','Зарплата':70000,'Стаж работы':4},
    {'ID':9,'Имя':'Виктор','Возраст':31,'Должность':'Юрист','Отдел':'Юридический','Зарплата':95000,'Стаж работы':10},
    {'ID':10,'Имя':'Алиса','Возраст':27,'Должность':'Дизайнер','Отдел':'Дизайн','Зарплата':62000,'Стаж работы':5},
    {'ID':11,'Имя':'Павел','Возраст':33,'Должность':'Администратор','Отдел':'Администрация','Зарплата':55000,'Стаж работы':7},
    {'ID':12,'Имя':'Светлана','Возраст':26,'Должность':'Тестировщик','Отдел':'Тестирование','Зарплата':67000,'Стаж работы':2},
    {'ID':13,'Имя':'Роман','Возраст':42,'Должность':'Финансист','Отдел':'Финансы','Зарплата':105000,'Стаж работы':20},
    {'ID':14,'Имя':'Татьяна','Возраст':37,'Должность':'Редактор','Отдел':'Редакция','Зарплата':72000,'Стаж работы':9},
    {'ID':15,'Имя':'Николай','Возраст':39,'Должность':'Логист','Отдел':'Логистика','Зарплата':75000,'Стаж работы':11},
    {'ID':16,'Имя':'Валерия','Возраст':24,'Должность':'SEO-специалист','Отдел':'SEO','Зарплата':64000,'Стаж работы':3},
    {'ID':17,'Имя':'Григорий','Возраст':50,'Должность':'Бухгалтер','Отдел':'Бухгалтерия','Зарплата':110000,'Стаж работы':25},
    {'ID':18,'Имя':'Юлия','Возраст':45,'Должность':'Директор','Отдел':'Финансы','Зарплата':150000,'Стаж работы':20},
    {'ID':19,'Имя':'Степан','Возраст':41,'Должность':'Экономист','Отдел':'Экономика','Зарплата':98000,'Стаж работы':14},
    {'ID':20,'Имя':'Василиса','Возраст':38,'Должность':'Проект-менеджер','Отдел':'Продажи','Зарплата':88000,'Стаж работы':8}
]

df = pd.DataFrame(data1)

df.to_json('dataz.json', index=False)
d = pd.read_json('dataz.json')
d.head(5).style.set_sticky()
# Out:
# <style type="text/css">
# #T_33dbd thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_33dbd tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_33dbd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33dbd_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_33dbd_level0_col1" class="col_heading level0 col1" >Имя</th>
#       <th id="T_33dbd_level0_col2" class="col_heading level0 col2" >Возраст</th>
#       <th id="T_33dbd_level0_col3" class="col_heading level0 col3" >Должность</th>
#       <th id="T_33dbd_level0_col4" class="col_heading level0 col4" >Отдел</th>
#       <th id="T_33dbd_level0_col5" class="col_heading level0 col5" >Зарплата</th>
#       <th id="T_33dbd_level0_col6" class="col_heading level0 col6" >Стаж работы</th>
#     </tr>
#   </thead>
# ...

# %% [markdown]
# **3.Доступ к данным ( .loc , .iloc , .at , .iat )**<br>
#
# Используя Таблицу 1:
# 1. Получите информацию о сотруднике с ID = 5 с помощью .loc[] .
# 2. Выведите возраст третьего сотрудника в таблице с .iloc[] .
# 3. Выведите название отдела для сотрудника "Мария" с .at[] .
# 4. Выведите зарплату сотрудника, находящегося в четвертой строке и пятом
# столбце, используя .iat[] .<br>
# Объясните разницу между .loc[] , .iloc[] , .at[] , .iat[] .

# %%
print(df.loc[df['ID']==5])
print(df.iloc[3])
print(df.at[3,'Отдел'])
print(df.iat[4,5])
# Out:
#    ID     Имя  Возраст   Должность Отдел  Зарплата  Стаж работы
# 4   5  Сергей       28  Специалист    HR     50000            3
# ID                       4
# Имя                  Мария
# Возраст                 35
# Должность      Программист
# Отдел                   IT
# Зарплата             80000
# Стаж работы              7
# Name: 3, dtype: object
# IT
# 50000

# %% [markdown]
# **4.Добавление новых столбцов и строк**
#
# Используя Таблицу 1:
# 1. Добавьте новый столбец "Категория зарплаты" :
# - "Низкая" – если Зарплата < 60000 .
# - "Средняя" – если 60000 ≤ Зарплата < 100000 .
# - "Высокая" – если Зарплата ≥ 100000 .
# 2. Добавьте нового сотрудника с данными:
#   df.loc[21] = ["Антон", 32, "Разработчик", "IT", 85000, 6]
# 3. Добавьте двух новых сотрудников одновременно, используя pd.concat().<br>
#   Выведите обновленный DataFrame

# %%
df["Категория зарплаты"] = df["Зарплата"].apply( 
lambda x: 'Низкая' if x < 60000 
    else 'Средняя' if 60000 <= x < 100000 
    else 'Высокая')
df.style.set_sticky()
# Out:
# <style type="text/css">
# #T_89360 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_89360 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_89360">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89360_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_89360_level0_col1" class="col_heading level0 col1" >Имя</th>
#       <th id="T_89360_level0_col2" class="col_heading level0 col2" >Возраст</th>
#       <th id="T_89360_level0_col3" class="col_heading level0 col3" >Должность</th>
#       <th id="T_89360_level0_col4" class="col_heading level0 col4" >Отдел</th>
#       <th id="T_89360_level0_col5" class="col_heading level0 col5" >Зарплата</th>
#       <th id="T_89360_level0_col6" class="col_heading level0 col6" >Стаж работы</th>
# ...

# %%
df.loc[21] = [22,"Антон", 32, "Разработчик", "IT", 85000, 6, "Средняя"]
df.style.set_sticky()
# Out:
# <style type="text/css">
# #T_f13d5 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_f13d5 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_f13d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f13d5_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_f13d5_level0_col1" class="col_heading level0 col1" >Имя</th>
#       <th id="T_f13d5_level0_col2" class="col_heading level0 col2" >Возраст</th>
#       <th id="T_f13d5_level0_col3" class="col_heading level0 col3" >Должность</th>
#       <th id="T_f13d5_level0_col4" class="col_heading level0 col4" >Отдел</th>
#       <th id="T_f13d5_level0_col5" class="col_heading level0 col5" >Зарплата</th>
#       <th id="T_f13d5_level0_col6" class="col_heading level0 col6" >Стаж работы</th>
# ...

# %%
data = [
   {'ID':1,'Имя':'Сер гей','Возраст':45,'Должность':'Клоун','Отдел':'IT','Зарплата':10000,'Стаж работы':2},
    {'ID':2,'Имя':'Георгий','Возраст':16,'Должность':'Гений','Отдел':'ИТ','Зарплата':75151515000,'Стаж работы': 70},
]
new=pd.DataFrame(data)
df=pd.concat([df,new], ignore_index=True)
df.style.set_sticky()
# Out:
# <style type="text/css">
# #T_37f63 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_37f63 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_37f63">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37f63_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_37f63_level0_col1" class="col_heading level0 col1" >Имя</th>
#       <th id="T_37f63_level0_col2" class="col_heading level0 col2" >Возраст</th>
#       <th id="T_37f63_level0_col3" class="col_heading level0 col3" >Должность</th>
#       <th id="T_37f63_level0_col4" class="col_heading level0 col4" >Отдел</th>
#       <th id="T_37f63_level0_col5" class="col_heading level0 col5" >Зарплата</th>
#       <th id="T_37f63_level0_col6" class="col_heading level0 col6" >Стаж работы</th>
# ...

# %% [markdown]
# **5.Удаление строк и столбцов**
#
# Используя Таблицу 1:
#
# 1. Удалите столбец "Категория зарплаты" с .drop() .
# 2. Удалите строку с ID = 10 .
# 3. Удалите все строки, где Стаж работы < 3 лет .
# 4. Удалите все столбцы, кроме Имя , Должность , Зарплата .<br>
#
# Выведите DataFrame после каждого шага.

# %%
df= df.drop(columns=["Категория зарплаты"])
print(df)

df= df.drop(index=[9])
print(df)

indices_to_drop = df[df['Стаж работы'] < 3].index
df_filtered = df.drop(indices_to_drop)
print("Отфильтрованная таблица:")
print(df_filtered)

df= df.drop(columns=['ID','Возраст','Отдел','Стаж работы'])
print(df)
# Out:
#     ID       Имя  Возраст        Должность        Отдел     Зарплата  \
# 0    1      Иван       25          Инженер           IT        60000
# 1    2     Ольга       30         Аналитик    Маркетинг        75000
# 2    3   Алексей       40         Менеджер      Продажи        90000
# 3    4     Мария       35      Программист           IT        80000
# 4    5    Сергей       28       Специалист           HR        50000
# 5    6      Анна       32      Разработчик           IT        85000
# 6    7   Дмитрий       45               HR           HR        48000
# 7    8     Елена       29       Маркетолог    Маркетинг        70000
# 8    9    Виктор       31            Юрист  Юридический        95000
# 9   16   Валерия       24   SEO-специалист          SEO        64000
# 10  17  Григорий       50        Бухгалтер  Бухгалтерия       110000
# 11  18      Юлия       45         Директор      Финансы       150000
# 12  19    Степан       41        Экономист    Экономика        98000
# ...

# %% [markdown]
# **6.Фильтрация данных ( query , isin , between )**
#
# Используя Таблицу 2:
# 1. Выберите всех клиентов из "Москва" или "Санкт-Петербург" , используя
# .isin() .
# 2. Выберите клиентов, у которых Баланс на счете от 100000 до 250000,
# используя .between() .
# 3. Отфильтруйте клиентов, у которых "Кредитная история" "Хорошая" и
# "Баланс на счете" > 150000 , используя .query() .<br>
#
# Выведите результаты каждого фильтра.

# %%
data2 = [
    {'ID':1,'Имя':'Иван','Возраст':34,'Город':'Москва','Баланс на счете':120000,'Кредитная история':'Хорошая'},
    {'ID':2,'Имя':'Ольга','Возраст':27,'Город':'Санкт-Петербург','Баланс на счете':80000,'Кредитная история':'Средняя'},
    {'ID':3,'Имя':'Алексей','Возраст':45,'Город':'Казань','Баланс на счете':150000,'Кредитная история':'Плохая'},
    {'ID':4,'Имя':'Мария','Возраст':38,'Город':'Новосибирск','Баланс на счете':200000,'Кредитная история':'Хорошая'},
    {'ID':5,'Имя':'Сергей','Возраст':29,'Город':'Екатеринбург','Баланс на счете':95000,'Кредитная история':'Средняя'},
    {'ID':6,'Имя':'Анна','Возраст':50,'Город':'Воронеж','Баланс на счете':300000,'Кредитная история':'Отличная'},
    {'ID':7,'Имя':'Дмитрий','Возраст':31,'Город':'Челябинск','Баланс на счете':140000,'Кредитная история':'Средняя'},
    {'ID':8,'Имя':'Елена','Возраст':40,'Город':'Краснодар','Баланс на счете':175000,'Кредитная история':'Хорошая'},
    {'ID':9,'Имя':'Виктор','Возраст':28,'Город':'Ростов-на-Дону','Баланс на счете':110000,'Кредитная история':'Плохая'},
    {'ID':10,'Имя':'Алиса','Возраст':33,'Город':'Уфа','Баланс на счете':98000,'Кредитная история':'Средняя'},
    {'ID':11,'Имя':'Павел','Возраст':46,'Город':'Омск','Баланс на счете':250000,'Кредитная история':'Хорошая'},
    {'ID':12,'Имя':'Светлана','Возраст':37,'Город':'Пермь','Баланс на счете':210000,'Кредитная история':'Отличная'},
    {'ID':13,'Имя':'Роман','Возраст':41,'Город':'Тюмень','Баланс на счете':135000,'Кредитная история':'Средняя'},
    {'ID':14,'Имя':'Татьяна','Возраст':25,'Город':'Саратов','Баланс на счете':155000,'Кредитная история':'Хорошая'},
    {'ID':15,'Имя':'Николай','Возраст':39,'Город':'Самара','Баланс на счете':125000,'Кредитная история':'Средняя'},
    {'ID':16,'Имя':'Валерия','Возраст':42,'Город':'Волгоград','Баланс на счете':180000,'Кредитная история':'Плохая'},
    {'ID':17,'Имя':'Григорий','Возраст':49,'Город':'Барнаул','Баланс на счете':275000,'Кредитная история':'Отличная'},
    {'ID':18,'Имя':'Юлия','Возраст':50,'Город':'Иркутск','Баланс на счете':320000,'Кредитная история':'Хорошая'},
    {'ID':19,'Имя':'Степан','Возраст':30,'Город':'Хабаровск','Баланс на счете':105000,'Кредитная история':'Средняя'},
    {'ID':20,'Имя':'Василиса','Возраст':35,'Город':'Томск','Баланс на счете':90000,'Кредитная история':'Плохая'}
]

df = pd.DataFrame(data2)

df_filtered = df[df["Город"].isin(["Москва", 'Санкт-Петербург'])]
print(df_filtered)

df_filtered = df[df['Баланс на счете'].between(100000, 250000)]
print(df_filtered)

df_filtered = df.query("`Кредитная история` == 'Хорошая' and `Баланс на счете` > 150000")  # Добавлен пробел после 'Хорошая'
print("\nКомбинированный фильтр:")
print(df_filtered)
# Out:
#    ID    Имя  Возраст            Город  Баланс на счете Кредитная история
# 0   1   Иван       34           Москва           120000           Хорошая
# 1   2  Ольга       27  Санкт-Петербург            80000           Средняя
#     ID       Имя  Возраст           Город  Баланс на счете Кредитная история
# 0    1      Иван       34          Москва           120000           Хорошая
# 2    3   Алексей       45          Казань           150000            Плохая
# 3    4     Мария       38     Новосибирск           200000           Хорошая
# 6    7   Дмитрий       31       Челябинск           140000           Средняя
# 7    8     Елена       40       Краснодар           175000           Хорошая
# 8    9    Виктор       28  Ростов-на-Дону           110000            Плохая
# 10  11     Павел       46            Омск           250000           Хорошая
# 11  12  Светлана       37           Пермь           210000          Отличная
# ...

# %% [markdown]
# **7.Подсчет значений ( count , value_counts , nunique )**
#
# Используя Таблицу 2:
# 1. Подсчитайте количество непустых значений в каждом столбце ( .count() ).
# 2. Определите частоту встречаемости значений в "Город" ( .value_counts() ).
# 3. Найдите количество уникальных значений в "Город" , "Возраст" , "Баланс
# на счете" ( .nunique() )
#
# Выведите результаты.

# %%
data2 = [
    {'ID':1,'Имя':'Иван','Возраст':34,'Город':'Москва','Баланс на счете':120000,'Кредитная история':'Хорошая'},
    {'ID':2,'Имя':'Ольга','Возраст':27,'Город':'Санкт-Петербург','Баланс на счете':80000,'Кредитная история':'Средняя'},
    {'ID':3,'Имя':'Алексей','Возраст':45,'Город':'Казань','Баланс на счете':150000,'Кредитная история':'Плохая'},
    {'ID':4,'Имя':'Мария','Возраст':38,'Город':'Новосибирск','Баланс на счете':200000,'Кредитная история':'Хорошая'},
    {'ID':5,'Имя':'Сергей','Возраст':29,'Город':'Екатеринбург','Баланс на счете':95000,'Кредитная история':'Средняя'},
    {'ID':6,'Имя':'Анна','Возраст':50,'Город':'Воронеж','Баланс на счете':300000,'Кредитная история':'Отличная'},
    {'ID':7,'Имя':'Дмитрий','Возраст':31,'Город':'Челябинск','Баланс на счете':140000,'Кредитная история':'Средняя'},
    {'ID':8,'Имя':'Елена','Возраст':40,'Город':'Краснодар','Баланс на счете':175000,'Кредитная история':'Хорошая'},
    {'ID':9,'Имя':'Виктор','Возраст':28,'Город':'Ростов-на-Дону','Баланс на счете':110000,'Кредитная история':'Плохая'},
    {'ID':10,'Имя':'Алиса','Возраст':33,'Город':'Уфа','Баланс на счете':98000,'Кредитная история':'Средняя'},
    {'ID':11,'Имя':'Павел','Возраст':46,'Город':'Омск','Баланс на счете':250000,'Кредитная история':'Хорошая'},
    {'ID':12,'Имя':'Светлана','Возраст':37,'Город':'Пермь','Баланс на счете':210000,'Кредитная история':'Отличная'},
    {'ID':13,'Имя':'Роман','Возраст':41,'Город':'Тюмень','Баланс на счете':135000,'Кредитная история':'Средняя'},
    {'ID':14,'Имя':'Татьяна','Возраст':25,'Город':'Саратов','Баланс на счете':155000,'Кредитная история':'Хорошая'},
    {'ID':15,'Имя':'Николай','Возраст':39,'Город':'Самара','Баланс на счете':125000,'Кредитная история':'Средняя'},
    {'ID':16,'Имя':'Валерия','Возраст':42,'Город':'Волгоград','Баланс на счете':180000,'Кредитная история':'Плохая'},
    {'ID':17,'Имя':'Григорий','Возраст':49,'Город':'Барнаул','Баланс на счете':275000,'Кредитная история':'Отличная'},
    {'ID':18,'Имя':'Юлия','Возраст':50,'Город':'Иркутск','Баланс на счете':320000,'Кредитная история':'Хорошая'},
    {'ID':19,'Имя':'Степан','Возраст':30,'Город':'Хабаровск','Баланс на счете':105000,'Кредитная история':'Средняя'},
    {'ID':20,'Имя':'Василиса','Возраст':35,'Город':'Томск','Баланс на счете':90000,'Кредитная история':'Плохая'}
]

df = pd.DataFrame(data2)

print(df.count(), end='\n\n')

print(df["Город"].value_counts(), end='\n\n')

print(df["Город"].nunique(), end='\n\n')
print(df["Возраст"].nunique(), end='\n\n')
df.rename(columns={"Баланс на счете": "Баланс_на_счете"}, inplace=True)
print(df["Баланс_на_счете"].nunique(), end='\n\n')
# Out:
# ID                   20
# Имя                  20
# Возраст              20
# Город                20
# Баланс на счете      20
# Кредитная история    20
# dtype: int64
#
# Город
# Москва             1
# Санкт-Петербург    1
# Хабаровск          1
# Иркутск            1
# Барнаул            1
# Волгоград          1
# Самара             1
# Саратов            1
# Тюмень             1
# Пермь              1
# Омск               1
# Уфа                1
# Ростов-на-Дону     1
# Краснодар          1
# Челябинск          1
# Воронеж            1
# Екатеринбург       1
# Новосибирск        1
# Казань             1
# Томск              1
# Name: count, dtype: int64
#
# 20
#
# 19
#
# 20

# %% [markdown]
# **8.Обнаружение пропусков ( isna , notna )**
#
# Используя Таблицу 3:
# 1. Подсчитайте количество NaN в каждом столбце ( .isna().sum() ).
# 2. Подсчитайте количество заполненных значений в каждом столбце
# ( .notna().sum() ).
# 3. Выведите DataFrame , оставив только строки, где нет пропущенных
# значений.<br>
# Объясните разницу между .isna() и .notna() .

# %%
import numpy as np

data3 = [
    {'ID': 1, 'Имя': 'Иван', 'Возраст': 34.0, 'Город': 'Москва', 'Баланс на счете': 120000.0, 'Кредитная история': 'Хорошая'},
    {'ID': 2, 'Имя': 'Ольга', 'Возраст': 27.0, 'Город': 'Санкт-Петербург', 'Баланс на счете': np.nan, 'Кредитная история': 'Средняя'},
    {'ID': 3, 'Имя': 'Алексей', 'Возраст': np.nan, 'Город': 'Казань', 'Баланс на счете': 150000.0, 'Кредитная история': 'Плохая'},
    {'ID': 4, 'Имя': 'Мария', 'Возраст': 38.0, 'Город': np.nan, 'Баланс на счете': 200000.0, 'Кредитная история': 'Хорошая'},
    {'ID': 5, 'Имя': 'Сергей', 'Возраст': 29.0, 'Город': 'Екатеринбург', 'Баланс на счете': np.nan, 'Кредитная история': np.nan},
    {'ID': 6, 'Имя': np.nan, 'Возраст': 50.0, 'Город': 'Воронеж', 'Баланс на счете': 300000.0, 'Кредитная история': 'Отличная'},
    {'ID': 7, 'Имя': 'Дмитрий', 'Возраст': 31.0, 'Город': np.nan, 'Баланс на счете': 140000.0, 'Кредитная история': 'Средняя'},
    {'ID': 8, 'Имя': 'Елена', 'Возраст': 40.0, 'Город': 'Краснодар', 'Баланс на счете': 175000.0, 'Кредитная история': 'Хорошая'},
    {'ID': 9, 'Имя': 'Виктор', 'Возраст': np.nan, 'Город': 'Ростов-на-Дону', 'Баланс на счете': 110000.0, 'Кредитная история': np.nan},
    {'ID': 10, 'Имя': 'Алиса', 'Возраст': 33.0, 'Город': 'Уфа', 'Баланс на счете': np.nan, 'Кредитная история': 'Средняя'},
    {'ID': 11, 'Имя': 'Павел', 'Возраст': 46.0, 'Город': 'Омск', 'Баланс на счете': 250000.0, 'Кредитная история': 'Хорошая'},
    {'ID': 12, 'Имя': np.nan, 'Возраст': 37.0, 'Город': 'Пермь', 'Баланс на счете': 210000.0, 'Кредитная история': 'Отличная'},
    {'ID': 13, 'Имя': 'Роман', 'Возраст': 41.0, 'Город': np.nan, 'Баланс на счете': 135000.0, 'Кредитная история': 'Средняя'},
    {'ID': 14, 'Имя': 'Татьяна', 'Возраст': 25.0, 'Город': 'Саратов', 'Баланс на счете': 155000.0, 'Кредитная история': np.nan},
    {'ID': 15, 'Имя': 'Николай', 'Возраст': np.nan, 'Город': 'Самара', 'Баланс на счете': 125000.0, 'Кредитная история': 'Средняя'},
    {'ID': 16, 'Имя': 'Валерия', 'Возраст': 42.0, 'Город': np.nan, 'Баланс на счете': np.nan, 'Кредитная история': 'Плохая'},
    {'ID': 17, 'Имя': 'Григорий', 'Возраст': 49.0, 'Город': 'Барнаул', 'Баланс на счете': 275000.0, 'Кредитная история': 'Отличная'},
    {'ID': 18, 'Имя': 'Юлия', 'Возраст': np.nan, 'Город': 'Иркутск', 'Баланс на счете': 320000.0, 'Кредитная история': 'Хорошая'},
    {'ID': 19, 'Имя': 'Степан', 'Возраст': 30.0, 'Город': 'Хабаровск', 'Баланс на счете': 105000.0, 'Кредитная история': 'Средняя'},
    {'ID': 20, 'Имя': 'Василиса', 'Возраст': 35.0, 'Город': 'Томск', 'Баланс на счете': 90000.0, 'Кредитная история': 'Плохая'}
]

df = pd.DataFrame(data3)

print(df.isna().sum(), end='\n\n')

print(df.notna().sum())

df_filt=df.dropna()
print(df_filt)
# Out:
# ID                   0
# Имя                  2
# Возраст              4
# Город                4
# Баланс на счете      4
# Кредитная история    3
# dtype: int64
#
# ID                   20
# Имя                  18
# Возраст              16
# Город                16
# Баланс на счете      16
# Кредитная история    17
# dtype: int64
#     ID       Имя  Возраст      Город  Баланс на счете Кредитная история
# 0    1      Иван     34.0     Москва         120000.0           Хорошая
# 7    8     Елена     40.0  Краснодар         175000.0           Хорошая
# 10  11     Павел     46.0       Омск         250000.0           Хорошая
# 16  17  Григорий     49.0    Барнаул         275000.0          Отличная
# 18  19    Степан     30.0  Хабаровск         105000.0           Средняя
# 19  20  Василиса     35.0      Томск          90000.0            Плохая

# %% [markdown]
# ##**Индивидуальное задание**

# %% [markdown]
# Написать программу на языке программирования Python для решения
# поставленной задачи (в репозитории должны присутствовать настройки требуемых
# пакетов для выбранного менеджера пакетов). Приложение должно использовать
# интерфейс командной строки (модуль argparse ) или графический интерфейс
# пользователя (модули tkinter , PySide2 , Kivy и т. д.). При работе с датой и
# временем использовать пакет datetime . Организовать чтение и сохранение
# данных из/в формат Parquet. Выполнить валидацию сохраненных данных с
# помощью сторонних приложений для работы с форматом Parquet, например
# https://github.com/mukunku/ParquetViewer. Организовать также удаление данных по
# одной из колонок DataFrame на выбор обучающихся. Номер варианта
# определяется по согласованию с преподавателем.<br>
# <br>
# Использовать DataFrame , содержащий следующие колонки: фамилия, имя;
# номер телефона; дата рождения (список из трех чисел). Написать программу,
# выполняющую следующие действия: ввод с клавиатуры данных и добавление
# строк в DataFrame ; записи должны быть размещены по алфавиту; вывод на
# экран информации о людях, чьи дни рождения приходятся на месяц, значение
# которого введено с клавиатуры; если таких нет, выдать на дисплей
# соответствующее сообщение
