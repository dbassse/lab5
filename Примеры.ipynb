# %%
import pandas as pd
s = pd.Series([10, 20, 30, 40], index=["a", "b", "c", "d"])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
data = {
"Возраст": [25, 30, 22],
"Город": ["Москва", "СПб", "Казань"]
}
df = pd.DataFrame(data, index=["Анна", "Иван", "Ольга"])
print(df)
# Out:
#        Возраст   Город
# Анна        25  Москва
# Иван        30     СПб
# Ольга       22  Казань

# %%
print(df["Возраст"])
# Out:
# Анна     25
# Иван     30
# Ольга    22
# Name: Возраст, dtype: int64

# %%
s = pd.Series([10, 20, 30], index=["a", "b", "c"])
df = s.to_frame(name="Значение")
print(df)
# Out:
#    Значение
# a        10
# b        20
# c        30

# %%
s = df["Значение"]
print(s)
# Out:
# a    10
# b    20
# c    30
# Name: Значение, dtype: int64

# %%
import pandas as pd
data = {
"Имя": ["Анна", "Иван", "Ольга"],
"Возраст": [25, 30, 22],
"Город": ["Москва", "СПб", "Казань"]
}
df = pd.DataFrame(data)
print(df)
# Out:
#      Имя  Возраст   Город
# 0   Анна       25  Москва
# 1   Иван       30     СПб
# 2  Ольга       22  Казань

# %%
ages = pd.Series([25, 30, 22], index=["a", "b", "c"])
cities = pd.Series(["Москва", "СПб", "Казань"], index=["a", "b", "c"])
df = pd.DataFrame({"Возраст": ages, "Город": cities})
print(df)
# Out:
#    Возраст   Город
# a       25  Москва
# b       30     СПб
# c       22  Казань

# %%
data = [
["Анна", 25, "Москва"],
["Иван", 30, "СПб"],
["Ольга", 22, "Казань"]
]
df = pd.DataFrame(data, columns=["Имя", "Возраст", "Город"])
print(df)
# Out:
#      Имя  Возраст   Город
# 0   Анна       25  Москва
# 1   Иван       30     СПб
# 2  Ольга       22  Казань

# %%
data = [
{"Имя": "Анна", "Возраст": 25, "Город": "Москва"},
{"Имя": "Иван", "Возраст": 30}, # "Город" пропущен
{"Имя": "Ольга", "Возраст": 22, "Город": "Казань"}
]
df = pd.DataFrame(data)
print(df)
# Out:
#      Имя  Возраст   Город
# 0   Анна       25  Москва
# 1   Иван       30     NaN
# 2  Ольга       22  Казань

# %%
import numpy as np
data = np.array([
["Анна", 25, "Москва"],
["Иван", 30, "СПб"],
["Ольга", 22, "Казань"]
])
df = pd.DataFrame(data, columns=["Имя", "Возраст", "Город"])
print(df)
# Out:
#      Имя Возраст   Город
# 0   Анна      25  Москва
# 1   Иван      30     СПб
# 2  Ольга      22  Казань

# %%
numeric_data = np.array([
[25, 65.5],
[30, 78.2],
[22, 54.3]
])
df = pd.DataFrame(numeric_data, columns=["Возраст", "Вес"])
print(df)
# Out:
#    Возраст   Вес
# 0     25.0  65.5
# 1     30.0  78.2
# 2     22.0  54.3

# %%
df = pd.DataFrame(columns=["Имя", "Возраст", "Город"])
print(df)
# Out:
# Empty DataFrame
# Columns: [Имя, Возраст, Город]
# Index: []

# %%
df.loc[0] = ["Анна", 25, "Москва"]
df.loc[1] = ["Иван", 30, "СПб"]
print(df)
# Out:
#     Имя  Возраст   Город
# 0  Анна       25  Москва
# 1  Иван       30     СПб

# %%
import pandas as pd
df = pd.read_csv("datapr.csv")
print(df.head()) # Выведем первые 5 строк
# Out:
#          Дата  Цена
# 0  2024-03-01   100
# 1  2024-03-02   110
# 2  2024-03-03   105
# 3  2024-03-04   120
# 4  2024-03-05   115

# %%
df = pd.read_csv("datapr.csv", sep=";", index_col=0, na_values=["?",
"N/A"])

# %%
df.to_csv("output.csv", index=False) # index=False — не сохранять индексы

# %%
data = {
    "Имя": ["Анна", "Иван", "Мария"],
    "Возраст": [25, 30, 28],
    "Город": ["Москва", "Санкт-Петербург", "Казань"]
}

# Преобразуем данные в DataFrame
df = pd.DataFrame(data)

# Сохраняем в Excel-файл (указываем движок openpyxl для .xlsx)
df.to_excel("datapr.xlsx", index=False, engine="openpyxl", sheet_name="Лист1")
df = pd.read_excel("datapr.xlsx", sheet_name="Лист1",engine='openpyxl')
print(df.head())
# Out:
#      Имя  Возраст            Город
# 0   Анна       25           Москва
# 1   Иван       30  Санкт-Петербург
# 2  Мария       28           Казань

# %%
data=[
{"Имя": "Анна", "Возраст": 25, "Город": "Москва"},
{"Имя": "Иван", "Возраст": 30, "Город": "СПб"},
{"Имя": "Ольга", "Возраст": 22, "Город": "Казань"}
]

df= pd.DataFrame(data)

df.to_json("output.json", orient="records", indent=4)

df = pd.read_json("output.json")
print(df.head())
# Out:
#      Имя  Возраст   Город
# 0   Анна       25  Москва
# 1   Иван       30     СПб
# 2  Ольга       22  Казань

# %%
data=[
{"Имя": "Анна", "Возраст": 25, "Город": "Москва"},
{"Имя": "Иван", "Возраст": 30, "Город": "СПб"},
{"Имя": "Ольга", "Возраст": 22, "Город": "Казань"}
]

df= pd.DataFrame(data)

df.to_parquet("output.parquet", engine="pyarrow", index=False)

df = pd.read_parquet("output.parquet")
print(df.head())
# Out:
#      Имя  Возраст   Город
# 0   Анна       25  Москва
# 1   Иван       30     СПб
# 2  Ольга       22  Казань

# %%
import sqlite3
data=[
{"Имя": "Анна", "Возраст": 25, "Город": "Москва"},
{"Имя": "Иван", "Возраст": 30, "Город": "СПб"},
{"Имя": "Ольга", "Возраст": 22, "Город": "Казань"}
]

df= pd.DataFrame(data)

df.to_sql("users", conn, if_exists="replace", index=False)

conn = sqlite3.connect("database.db") # Подключение к базе данных
query = "SELECT * FROM users"
df = pd.read_sql(query, conn)
print(df.head())
# Out:
#      Имя  Возраст   Город
# 0   Анна       25  Москва
# 1   Иван       30     СПб
# 2  Ольга       22  Казань

# %%
import pandas as pd
# Создадим небольшой DataFrame
data = {
"Имя": ["Анна", "Иван", "Ольга", "Петр", "Мария", "Сергей"],
"Возраст": [25, 30, 22, 40, 35, 28],
"Город": ["Москва", "СПб", "Казань", "Новосибирск",
"Екатеринбург", "Сочи"]
}
df = pd.DataFrame(data)
# Выведем первые 3 строки
print(df.head(3))
# Out:
#      Имя  Возраст   Город
# 0   Анна       25  Москва
# 1   Иван       30     СПб
# 2  Ольга       22  Казань

# %%
print(df.tail(2)) # Последние 2 строки
# Out:
#       Имя  Возраст         Город
# 4   Мария       35  Екатеринбург
# 5  Сергей       28          Сочи

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Имя      6 non-null      object
#  1   Возраст  6 non-null      int64
#  2   Город    6 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 276.0+ bytes

# %%
print(df.describe())
# Out:
#         Возраст
# count   6.00000
# mean   30.00000
# std     6.60303
# min    22.00000
# 25%    25.75000
# 50%    29.00000
# 75%    33.75000
# max    40.00000

# %%
print(df.describe(include="object"))
# Out:
#          Имя   Город
# count      6       6
# unique     6       6
# top     Анна  Москва
# freq       1       1

# %%
import pandas as pd
data = {
"Имя": ["Анна", "Иван", "Ольга", "Петр"],
"Возраст": [25, 30, 22, 40],
"Город": ["Москва", "СПб", "Казань", "Новосибирск"]
}
df = pd.DataFrame(data, index=["a", "b", "c", "d"])
print(df)
# Out:
#      Имя  Возраст        Город
# a   Анна       25       Москва
# b   Иван       30          СПб
# c  Ольга       22       Казань
# d   Петр       40  Новосибирск

# %%
print(df.loc["b"])
# Out:
# Имя        Иван
# Возраст      30
# Город       СПб
# Name: b, dtype: object

# %%
print(df.loc["c", "Город"]) # Получим город Ольги
# Out:
# Казань

# %%
print(df.loc[["a", "c"]]) # Выбор строк "a" и "c"
# Out:
#      Имя  Возраст   Город
# a   Анна       25  Москва
# c  Ольга       22  Казань

# %%
print(df.loc[:, ["Имя", "Город"]]) # Выбор всех строк, но только двух столбцов
# Out:
#      Имя        Город
# a   Анна       Москва
# b   Иван          СПб
# c  Ольга       Казань
# d   Петр  Новосибирск

# %%
print(df.loc[df["Возраст"] > 25]) # Выведем строки, где возраст больше 25
# Out:
#     Имя  Возраст        Город
# b  Иван       30          СПб
# d  Петр       40  Новосибирск

# %%
print(df.iloc[1]) # Вторая строка (нумерация с 0)
# Out:
# Имя        Иван
# Возраст      30
# Город       СПб
# Name: b, dtype: object

# %%
print(df.iloc[2, 2]) # 3-я строка, 3-й столбец (Город Ольги)
# Out:
# Казань

# %%
print(df.iloc[[0, 2]]) # Строки 0 и 2 (Анна и Ольга)
# Out:
#      Имя  Возраст   Город
# a   Анна       25  Москва
# c  Ольга       22  Казань

# %%
print(df.iloc[1:3]) # Выбираем строки с 1 по 2 (не включая 3)
# Out:
#      Имя  Возраст   Город
# b   Иван       30     СПб
# c  Ольга       22  Казань

# %%
print(df.iloc[:, [0, 2]]) # Все строки, но только 1-й и 3-й столбцы
# Out:
#      Имя        Город
# a   Анна       Москва
# b   Иван          СПб
# c  Ольга       Казань
# d   Петр  Новосибирск

# %%
print(df.at["c", "Город"]) # Город Ольги
# Out:
# Казань

# %%
print(df.iat[2, 2]) # Город Ольги (3-я строка, 3-й столбец)
# Out:
# Казань

# %%
import pandas as pd
data = {
"Имя": ["Анна", "Иван", "Ольга"],
"Возраст": [25, 30, 22]
}
df = pd.DataFrame(data)
df["Город"] = ["Москва", "СПб", "Казань"] # Добавляем новый столбец
print(df)
# Out:
#      Имя  Возраст   Город
# 0   Анна       25  Москва
# 1   Иван       30     СПб
# 2  Ольга       22  Казань

# %%
df["Страна"] = "Россия"
print(df)
# Out:
#      Имя  Возраст   Город  Страна
# 0   Анна       25  Москва  Россия
# 1   Иван       30     СПб  Россия
# 2  Ольга       22  Казань  Россия

# %%
df["Возраст_в_месяцах"] = df["Возраст"] * 12
print(df)
# Out:
#      Имя  Возраст   Город  Страна  Возраст_в_месяцах
# 0   Анна       25  Москва  Россия                300
# 1   Иван       30     СПб  Россия                360
# 2  Ольга       22  Казань  Россия                264

# %%
df = df.assign(Зарплата=[50000, 60000, 45000])
print(df)
# Out:
#      Имя  Возраст   Город  Страна  Возраст_в_месяцах  Зарплата
# 0   Анна       25  Москва  Россия                300     50000
# 1   Иван       30     СПб  Россия                360     60000
# 2  Ольга       22  Казань  Россия                264     45000

# %%
df["Категория возраста"] = df["Возраст"].apply(lambda x: "Молодой" if
x < 30 else "Взрослый")
print(df)
# Out:
#      Имя  Возраст   Город  Страна  Возраст_в_месяцах  Зарплата  \
# 0   Анна       25  Москва  Россия                300     50000
# 1   Иван       30     СПб  Россия                360     60000
# 2  Ольга       22  Казань  Россия                264     45000
#
#   Категория возраста
# 0            Молодой
# 1           Взрослый
# 2            Молодой

# %%
df.loc[3] = ["Петр", 40, "Новосибирск", "Россия", 5000, 797, "Молодой"]
print(df)
# Out:
#      Имя  Возраст        Город  Страна  Возраст_в_месяцах  Зарплата  \
# 0   Анна       25       Москва  Россия                300     50000
# 1   Иван       30          СПб  Россия                360     60000
# 2  Ольга       22       Казань  Россия                264     45000
# 3   Петр       40  Новосибирск  Россия               5000       797
#
#   Категория возраста
# 0            Молодой
# 1           Взрослый
# 2            Молодой
# 3            Молодой

# %%
new_row = {"Имя": "Сергей", "Возраст": 35, "Город": "Сочи", "Страна":
"Россия"}
df = df.append(new_row, ignore_index=True)
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_736\1521394399.py in ?()
#       1 new_row = {"Имя": "Сергей", "Возраст": 35, "Город": "Сочи", "Страна":
#       2 "Россия"}
# ----> 3 df = df.append(new_row, ignore_index=True)
#       4 print(df)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
new_data = pd.DataFrame([{"Имя": "Алексей", "Возраст": 29, "Город":
"Томск", "Страна": "Россия"}])
df = pd.concat([df, new_data], ignore_index=True)
print(df)
# Out:
#        Имя  Возраст        Город  Страна  Возраст_в_месяцах  Зарплата  \
# 0     Анна       25       Москва  Россия              300.0   50000.0
# 1     Иван       30          СПб  Россия              360.0   60000.0
# 2    Ольга       22       Казань  Россия              264.0   45000.0
# 3     Петр       40  Новосибирск  Россия             5000.0     797.0
# 4  Алексей       29        Томск  Россия                NaN       NaN
#
#   Категория возраста
# 0            Молодой
# 1           Взрослый
# 2            Молодой
# 3            Молодой
# 4                NaN

# %%
new_rows = pd.DataFrame([{"Имя": "Дмитрий", "Возраст": 31, "Город": "Самара", "Страна":
"Россия"},
{"Имя": "Елена", "Возраст": 27, "Город": "Воронеж", "Страна":
"Россия"}
])
df = pd.concat([df, new_rows], ignore_index=True)
print(df)
# Out:
#        Имя  Возраст        Город  Страна  Возраст_в_месяцах  Зарплата  \
# 0     Анна       25       Москва  Россия              300.0   50000.0
# 1     Иван       30          СПб  Россия              360.0   60000.0
# 2    Ольга       22       Казань  Россия              264.0   45000.0
# 3     Петр       40  Новосибирск  Россия             5000.0     797.0
# 4  Алексей       29        Томск  Россия                NaN       NaN
# 5  Дмитрий       31       Самара  Россия                NaN       NaN
# 6    Елена       27      Воронеж  Россия                NaN       NaN
#
#   Категория возраста
# 0            Молодой
# 1           Взрослый
# 2            Молодой
# 3            Молодой
# 4                NaN
# 5                NaN
# 6                NaN

# %%
df.loc["новый"] = ["Артем", 33, "Калуга", "Россия",3,3,0]
print(df)
# Out:
#            Имя  Возраст        Город  Страна  Возраст_в_месяцах  Зарплата  \
# 0         Анна       25       Москва  Россия              300.0   50000.0
# 1         Иван       30          СПб  Россия              360.0   60000.0
# 2        Ольга       22       Казань  Россия              264.0   45000.0
# 3         Петр       40  Новосибирск  Россия             5000.0     797.0
# 4      Алексей       29        Томск  Россия                NaN       NaN
# 5      Дмитрий       31       Самара  Россия                NaN       NaN
# 6        Елена       27      Воронеж  Россия                NaN       NaN
# новый    Артем       33       Калуга  Россия                3.0       3.0
#
#       Категория возраста
# 0                Молодой
# 1               Взрослый
# 2                Молодой
# 3                Молодой
# 4                    NaN
# 5                    NaN
# 6                    NaN
# новый                  0

# %%
import pandas as pd
data = {
"Имя": ["Анна", "Иван", "Ольга"],
"Возраст": [25, 30, 22],
"Город": ["Москва", "СПб", "Казань"],
"Зарплата": [50000, 60000, 45000]
}
df = pd.DataFrame(data)
# Удаляем столбец "Зарплата"
df = df.drop(columns=["Зарплата"])
print(df)
# Out:
#      Имя  Возраст   Город
# 0   Анна       25  Москва
# 1   Иван       30     СПб
# 2  Ольга       22  Казань

# %%
df = df.drop(columns=["Возраст", "Город"])
print(df)
# Out:
#      Имя
# 0   Анна
# 1   Иван
# 2  Ольга

# %%
del df["Имя"]
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2]

# %%
df["Имя"] = ["Анна", "Иван", "Ольга"] # Вернем столбец для примера
удаленный_столбец = df.pop("Имя")
print(удаленный_столбец)
# Out:
# 0     Анна
# 1     Иван
# 2    Ольга
# Name: Имя, dtype: object

# %%
df = pd.DataFrame(data) # Восстанавливаем DataFrame
# Удаляем строку с индексом 1 (Иван)
df = df.drop(index=1)
print(df)
# Out:
#      Имя  Возраст   Город  Зарплата
# 0   Анна       25  Москва     50000
# 2  Ольга       22  Казань     45000

# %%
df = df.drop(index=[0, 2]) # Удаляем Анну и Ольгу
print(df)
# Out:
# Empty DataFrame
# Columns: [Имя, Возраст, Город, Зарплата]
# Index: []

# %%
df = pd.DataFrame(data) # Восстанавливаем DataFrame
# Оставляем только людей старше 25 лет
df = df[df["Возраст"] > 25]
print(df)
# Out:
#     Имя  Возраст Город  Зарплата
# 1  Иван       30   СПб     60000

# %%
df = df.reset_index(drop=True) # Сбрасываем индексы
print(df)
# Out:
#     Имя  Возраст Город  Зарплата
# 0  Иван       30   СПб     60000

# %%
df.loc[3] = ["Мария", None, "Самара", 55000] # Добавим строку спропуском
df = df.dropna() # Удалим все строки с пропущенными значениями
print(df)
# Out:
#     Имя Возраст Город  Зарплата
# 0  Иван      30   СПб     60000

# %%
df = pd.DataFrame({
"Имя": ["Анна", "Иван", "Анна", "Ольга"],
"Возраст": [25, 30, 25, 22]
})
df = df.drop_duplicates()
print(df)
# Out:
#      Имя  Возраст
# 0   Анна       25
# 1   Иван       30
# 3  Ольга       22

# %%
df = df.drop_duplicates(subset=["Имя"])
print(df)
# Out:
#      Имя  Возраст
# 0   Анна       25
# 1   Иван       30
# 3  Ольга       22

# %%
import pandas as pd
data = {
"Имя": ["Анна", "Иван", "Ольга", "Петр", "Мария"],
"Возраст": [25, 30, 22, 40, 35],
"Город": ["Москва", "СПб", "Казань", "Новосибирск", "СПб"],
"Зарплата": [50000, 60000, 45000, 70000, 65000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#      Имя  Возраст        Город  Зарплата
# 0   Анна       25       Москва     50000
# 1   Иван       30          СПб     60000
# 2  Ольга       22       Казань     45000
# 3   Петр       40  Новосибирск     70000
# 4  Мария       35          СПб     65000

# %%
df_filtered = df.query("Возраст > 30")
print(df_filtered)
# Out:
#      Имя  Возраст        Город  Зарплата
# 3   Петр       40  Новосибирск     70000
# 4  Мария       35          СПб     65000

# %%
df_filtered = df.query("Город == 'СПб' and Зарплата > 60000")
print(df_filtered)
# Out:
#      Имя  Возраст Город  Зарплата
# 4  Мария       35   СПб     65000

# %%
min_age = 25
df_filtered = df.query("Возраст > @min_age")
print(df_filtered)
# Out:
#      Имя  Возраст        Город  Зарплата
# 1   Иван       30          СПб     60000
# 3   Петр       40  Новосибирск     70000
# 4  Мария       35          СПб     65000

# %%
df_filtered = df[df["Город"].isin(["Москва", "СПб"])]
print(df_filtered)
# Out:
#      Имя  Возраст   Город  Зарплата
# 0   Анна       25  Москва     50000
# 1   Иван       30     СПб     60000
# 4  Мария       35     СПб     65000

# %%
df_filtered = df[~df["Город"].isin(["Москва", "СПб"])]
print(df_filtered)
# Out:
#      Имя  Возраст        Город  Зарплата
# 2  Ольга       22       Казань     45000
# 3   Петр       40  Новосибирск     70000

# %%
df_filtered = df[df["Возраст"].between(25, 35)]
print(df_filtered)
# Out:
#      Имя  Возраст   Город  Зарплата
# 0   Анна       25  Москва     50000
# 1   Иван       30     СПб     60000
# 4  Мария       35     СПб     65000

# %%
df_filtered = df[df["Возраст"].between(25, 35, inclusive="neither")]
print(df_filtered)
# Out:
#     Имя  Возраст Город  Зарплата
# 1  Иван       30   СПб     60000

# %%
import pandas as pd
data = {"Имя": ["Анна", "Иван", "Ольга", "Петр", None],
"Возраст": [25, 30, 22, None, 35],
"Город": ["Москва", "СПб", "Казань", "Новосибирск", "СПб"]
}
df = pd.DataFrame(data)
print(df)
# Out:
#      Имя  Возраст        Город
# 0   Анна     25.0       Москва
# 1   Иван     30.0          СПб
# 2  Ольга     22.0       Казань
# 3   Петр      NaN  Новосибирск
# 4   None     35.0          СПб

# %%
print(df.count())
# Out:
# Имя        4
# Возраст    4
# Город      5
# dtype: int64

# %%
print(df["Город"].value_counts())
# Out:
# Город
# СПб            2
# Москва         1
# Казань         1
# Новосибирск    1
# Name: count, dtype: int64

# %%
print(df["Город"].value_counts(sort=False))
# Out:
# Город
# Москва         1
# СПб            2
# Казань         1
# Новосибирск    1
# Name: count, dtype: int64

# %%
print(df["Имя"].value_counts(dropna=False))
# Out:
# Имя
# Анна     1
# Иван     1
# Ольга    1
# Петр     1
# None     1
# Name: count, dtype: int64

# %%
print(df.nunique())
# Out:
# Имя        4
# Возраст    4
# Город      4
# dtype: int64

# %%
print(df["Имя"].nunique(dropna=False))
# Out:
# 5

# %%
print(df.isna().sum())
# Out:
# Имя        1
# Возраст    1
# Город      0
# dtype: int64

# %%
import pandas as pd
data = {
"Имя": ["Анна", "Иван", "Ольга", "Петр", "Мария"],
"Возраст": [25, 30, 22, 40, 35],
"Зарплата": [50000, 60000, 45000, 70000, 65000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#      Имя  Возраст  Зарплата
# 0   Анна       25     50000
# 1   Иван       30     60000
# 2  Ольга       22     45000
# 3   Петр       40     70000
# 4  Мария       35     65000

# %%
df_sorted = df.sort_values(by="Возраст")
print(df_sorted)
# Out:
#      Имя  Возраст  Зарплата
# 2  Ольга       22     45000
# 0   Анна       25     50000
# 1   Иван       30     60000
# 4  Мария       35     65000
# 3   Петр       40     70000

# %%
df_sorted = df.sort_values(by="Возраст", ascending=False)
print(df_sorted)
# Out:
#      Имя  Возраст  Зарплата
# 3   Петр       40     70000
# 4  Мария       35     65000
# 1   Иван       30     60000
# 0   Анна       25     50000
# 2  Ольга       22     45000

# %%
df_sorted = df.sort_values(by=["Возраст", "Зарплата"], ascending=
[True, False])
print(df_sorted)
# Out:
#      Имя  Возраст  Зарплата
# 2  Ольга       22     45000
# 0   Анна       25     50000
# 1   Иван       30     60000
# 4  Мария       35     65000
# 3   Петр       40     70000

# %%
df.loc[5] = ["Елена", None, 55000] # Добавляем строку с NaN в
"Возраст"
df_sorted = df.sort_values(by="Возраст", na_position="first")
print(df_sorted)
# Out:
#      Имя Возраст  Зарплата
# 5  Елена    None     55000
# 2  Ольга      22     45000
# 0   Анна      25     50000
# 1   Иван      30     60000
# 4  Мария      35     65000
# 3   Петр      40     70000

# %%
df_sorted = df.sort_index()
print(df_sorted)
# Out:
#      Имя Возраст  Зарплата
# 0   Анна      25     50000
# 1   Иван      30     60000
# 2  Ольга      22     45000
# 3   Петр      40     70000
# 4  Мария      35     65000
# 5  Елена    None     55000

# %%
df_sorted = df.sort_index(ascending=False)
print(df_sorted)
# Out:
#      Имя Возраст  Зарплата
# 5  Елена    None     55000
# 4  Мария      35     65000
# 3   Петр      40     70000
# 2  Ольга      22     45000
# 1   Иван      30     60000
# 0   Анна      25     50000

# %%
df = pd.DataFrame({
"Имя": ["Анна", "Иван", "Ольга"],
"Возраст": [25, 30, 22],
"Город": ["Москва", "СПб", "Казань"]
})
print(df)
# Out:
#      Имя  Возраст   Город
# 0   Анна       25  Москва
# 1   Иван       30     СПб
# 2  Ольга       22  Казань

# %%
from IPython.display import display
display(df)
# Out:
#      Имя  Возраст   Город
# 0   Анна       25  Москва
# 1   Иван       30     СПб
# 2  Ольга       22  Казань

# %%
df.head(5)
# Out:
#      Имя  Возраст   Город
# 0   Анна       25  Москва
# 1   Иван       30     СПб
# 2  Ольга       22  Казань

# %%
df.tail(3)
# Out:
#      Имя  Возраст   Город
# 0   Анна       25  Москва
# 1   Иван       30     СПб
# 2  Ольга       22  Казань

# %%
pd.set_option("display.max_rows", 100)

# %%
pd.set_option("display.max_columns", 50)

# %%
pd.set_option("display.max_colwidth", None)

# %%
pd.set_option("display.float_format", "{:.2f}".format)

# %%
df.style.set_sticky()
# Out:
# <style type="text/css">
# #T_ebbb5 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_ebbb5 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_ebbb5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebbb5_level0_col0" class="col_heading level0 col0" >Имя</th>
#       <th id="T_ebbb5_level0_col1" class="col_heading level0 col1" >Возраст</th>
#       <th id="T_ebbb5_level0_col2" class="col_heading level0 col2" >Город</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebbb5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ebbb5_row0_col0" class="data row0 col0" >Анна</td>
#       <td id="T_ebbb5_row0_col1" class="data row0 col1" >25</td>
#       <td id="T_ebbb5_row0_col2" class="data row0 col2" >Москва</td>
#     </tr>
#     <tr>
#       <th id="T_ebbb5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ebbb5_row1_col0" class="data row1 col0" >Иван</td>
#       <td id="T_ebbb5_row1_col1" class="data row1 col1" >30</td>
#       <td id="T_ebbb5_row1_col2" class="data row1 col2" >СПб</td>
#     </tr>
#     <tr>
#       <th id="T_ebbb5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ebbb5_row2_col0" class="data row2 col0" >Ольга</td>
#       <td id="T_ebbb5_row2_col1" class="data row2 col1" >22</td>
#       <td id="T_ebbb5_row2_col2" class="data row2 col2" >Казань</td>
#     </tr>
#   </tbody>
# </table>

# %%
import qgrid
qgrid_widget = qgrid.show_grid(df, show_toolbar=True)
qgrid_widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
from tabulate import tabulate
print(tabulate(df, headers="keys", tablefmt="github"))
# Out:
# |    | Имя   |   Возраст | Город   |
# |----|-------|-----------|---------|
# |  0 | Анна  |        25 | Москва  |
# |  1 | Иван  |        30 | СПб     |
# |  2 | Ольга |        22 | Казань  |

# %%
df.style.set_properties(**{"background-color": "lightgray", "color":
"black"})
# Out:
# <style type="text/css">
# #T_b6d62_row0_col0, #T_b6d62_row0_col1, #T_b6d62_row0_col2, #T_b6d62_row1_col0, #T_b6d62_row1_col1, #T_b6d62_row1_col2, #T_b6d62_row2_col0, #T_b6d62_row2_col1, #T_b6d62_row2_col2 {
#   background-color: lightgray;
#   color: black;
# }
# </style>
# <table id="T_b6d62">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6d62_level0_col0" class="col_heading level0 col0" >Имя</th>
#       <th id="T_b6d62_level0_col1" class="col_heading level0 col1" >Возраст</th>
#       <th id="T_b6d62_level0_col2" class="col_heading level0 col2" >Город</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6d62_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6d62_row0_col0" class="data row0 col0" >Анна</td>
#       <td id="T_b6d62_row0_col1" class="data row0 col1" >25</td>
#       <td id="T_b6d62_row0_col2" class="data row0 col2" >Москва</td>
#     </tr>
#     <tr>
#       <th id="T_b6d62_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b6d62_row1_col0" class="data row1 col0" >Иван</td>
#       <td id="T_b6d62_row1_col1" class="data row1 col1" >30</td>
#       <td id="T_b6d62_row1_col2" class="data row1 col2" >СПб</td>
#     </tr>
#     <tr>
#       <th id="T_b6d62_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b6d62_row2_col0" class="data row2 col0" >Ольга</td>
#       <td id="T_b6d62_row2_col1" class="data row2 col1" >22</td>
#       <td id="T_b6d62_row2_col2" class="data row2 col2" >Казань</td>
#     </tr>
#   </tbody>
# </table>

# %%
html_table = df.to_html(\)
with open("table.html", "w", encoding="utf-8") as f:
f.write(html_table)
# Out:
#   Cell In[145], line 3
#     f.write(html_table)
#     ^
# IndentationError: expected an indented block after 'with' statement on line 2
